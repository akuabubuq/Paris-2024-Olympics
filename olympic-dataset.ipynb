# %%
#Import Library

# %%
import pandas as pd

# %%
#Load the dataset

# %%
df = pd.read_csv("olympic_results.csv")

# %%
#Overview of data

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162804 entries, 0 to 162803
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   discipline_title       162804 non-null  object
#  1   event_title            162804 non-null  object
#  2   slug_game              162804 non-null  object
#  3   participant_type       162804 non-null  object
#  4   medal_type             20206 non-null   object
#  5   athletes               7976 non-null    object
#  6   rank_equal             32526 non-null   object
#  7   rank_position          158926 non-null  object
#  8   country_name           162804 non-null  object
#  9   country_code           157768 non-null  object
#  10  country_3_letter_code  162804 non-null  object
#  11  athlete_url            129991 non-null  object
#  12  athlete_full_name      141646 non-null  object
#  13  value_unit             78646 non-null   object
# ...

# %%
print(df.head())
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                             athletes rank_equal rank_position  \
# 0  [('Stefania CONSTANTINI', 'https://olympics.co...      False             1
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en...      False             2
# 2  [('Almida DE VAL', 'https://olympics.com/en/at...      False             3
# 3  [('Jennifer DODDS', 'https://olympics.com/en/a...      False             4
# 4  [('Rachel HOMAN', 'https://olympics.com/en/ath...      False             5
#
# ...

# %%
#Checking missing value

# %%
print(df.isnull().sum())
# Out:
# discipline_title              0
# event_title                   0
# slug_game                     0
# participant_type              0
# medal_type               142598
# athletes                 154828
# rank_equal               130278
# rank_position              3878
# country_name                  0
# country_code               5036
# country_3_letter_code         0
# athlete_url               32813
# athlete_full_name         21158
# value_unit                84158
# value_type                72755
# dtype: int64

# %%
#Based on the overview of data, we can gain two insight on how to handle the data here:
#1. We've found that athlete_full_name have a lot of null values. Since we will use this data, we will look further into this column

# %%
#1. Check athlete_full_name column type

# %%
null_athlete = df[df['athlete_full_name'].isnull()]

# %%
display(null_athlete)
# Out:
#            discipline_title  \
# 0                   Curling
# 1                   Curling
# 2                   Curling
# 3                   Curling
# 4                   Curling
# ...                     ...
# 162759       Figure skating
# 162760       Figure skating
# 162761       Figure skating
# 162762       Figure skating
# 162803  Gymnastics Artistic
#
#                                               event_title       slug_game  \
# 0                                           Mixed Doubles    beijing-2022
# 1                                           Mixed Doubles    beijing-2022
# 2                                           Mixed Doubles    beijing-2022
# 3                                           Mixed Doubles    beijing-2022
# 4                                           Mixed Doubles    beijing-2022
# ...                                                   ...             ...
# 162759                                  Ice dancing mixed  innsbruck-1976
# ...

# %%
#We see that NaN values mostly are team sport competition. So we will ignore NaN value in athlete_full_name column for now.

unique_event = null_athlete['event_title'].unique()

# %%
display(df)
# Out:
#            discipline_title  \
# 0                   Curling
# 1                   Curling
# 2                   Curling
# 3                   Curling
# 4                   Curling
# ...                     ...
# 162799          Ski Jumping
# 162800          Ski Jumping
# 162801          Ski Jumping
# 162802          Ski Jumping
# 162803  Gymnastics Artistic
#
#                                               event_title      slug_game  \
# 0                                           Mixed Doubles   beijing-2022
# 1                                           Mixed Doubles   beijing-2022
# 2                                           Mixed Doubles   beijing-2022
# 3                                           Mixed Doubles   beijing-2022
# 4                                           Mixed Doubles   beijing-2022
# ...                                                   ...            ...
# 162799                         Normal Hill Individual men  chamonix-1924
# ...

# %%
#Now we have a column which count number of athletes in a column, to know how many athletes is represented in a team game
#Now let's drop column that we didn't need
#Based on the objectives of the analysis, we only need 7 column, and the analysis focus will be only for Indonesia, which is; 

#competition = from discipline_title
#event from = from event_title
#edition = from slug_game
#participant_type = from participant_type
#medal = from medal_type
#athletes = from athelete_full_name
#country = from country_name, filter = Indonesia
#no of athletes = from counting number of athletes

#we will rename the column as mentioned above, with each column represent:

#competition = sport names/category for the competition
#event = type/category of competition (individual, team, etc.)
#edition = edition of olympic games, identified by the host city and the year in which the event took place
#participant_type = classification or category involved in a competition
#medal = medals awarded to athletes for a specific competition.
#athletes = name of the athletes
#country = country of the athletes that being represented.

# %%
#dropping columns

df = df.drop(columns=['rank_equal','athletes','rank_position','country_code','country_3_letter_code','athlete_url','value_unit','value_type'])

# %%
display(df)
# Out:
#        discipline_title                         event_title       slug_game  \
# 3809           Shooting         50m Rifle 3 Positions women      tokyo-2020
# 3994           Shooting                 10m Air Rifle women      tokyo-2020
# 6576          Badminton                       Men's Doubles      tokyo-2020
# 6579          Badminton                       Men's Doubles      tokyo-2020
# 6589          Badminton                     Women's Doubles      tokyo-2020
# ...                 ...                                 ...             ...
# 130947    Weightlifting       56 - 60kg (featherweight) men  melbourne-1956
# 131078         Shooting  25m rapid fire pistol 60 shots men  melbourne-1956
# 132134         Football                        football men  melbourne-1956
# 133847        Athletics                       high jump men   helsinki-1952
# 134280    Weightlifting       60 - 67.5kg (lightweight) men   helsinki-1952
#
# ...

# %%
#Filter all except Indonesia

df = df[df['country_name'] == 'Indonesia']

# %%
#Now the data has been cleaned and ready to be visualized.
